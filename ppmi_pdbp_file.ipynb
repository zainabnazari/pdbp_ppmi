# %% [markdown]
# # The table for RNA-Seq from PPMI and PDBP
# The tables are seperated from their diagnosis and sex values, in this part we combine them accordingly.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from datetime import datetime

# %%
path1=Path("/Users/zainabnazari/Desktop/pdbp/PPMI_PDBP_Log2CPM_sex_effect_removed_Norm_Quantile_together_PD_CTR")

# %% [markdown]
# # PPMI

# %%
pdbp_ppmi_data1=pd.read_csv(path1/"PPMI_subset_from_PPMI_PDBP_shared_genes_Log2CPM_sex_effect_removed_QuantileNorm_02giu2024.txt",delimiter='\t')
t_ppmi = pdbp_ppmi_data1.T

# %%
t_ppmi.reset_index(inplace=True)

# %%
t_ppmi['index']= t_ppmi['index'].str[1:]

# %%
t_ppmi.rename(columns={'index':'ID'}, inplace=True)

# %%
t_ppmi.set_index('ID', inplace=True)

# %%
t_ppmi
# Out:
#       ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# ID
# 3000        -0.101375        -2.999518         4.328498         6.049779
# 3001        -0.070030        -2.736090         5.246508         6.163900
# 3002         1.259571        -1.404902         5.358119         6.074396
# 3003        -1.071352        -2.890159         5.247370         6.124415
# 3004        -0.499520        -2.414768         5.351478         6.352868
# ...               ...              ...              ...              ...
# 4102         0.394976        -3.020122         5.379363         6.271351
# 4108        -1.064643        -2.870947         4.891916         6.071242
# 4115        -0.626887        -2.947472         5.040913         6.138357
# 4136        -1.850876        -2.993623         4.164878         5.503493
# 4139        -0.424039        -3.068511         5.312002         6.205509
#
#       ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# ID
# 3000         4.211890         8.784764         2.173793         4.125101
# 3001         4.088958         8.628968         3.412540         4.231814
# 3002         4.424164         8.762913         2.727398         4.769609
# 3003         4.354913         8.363715         4.113420         4.505387
# 3004         4.315031         9.066409         4.021306         4.289712
# ...               ...              ...              ...              ...
# 4102         4.256049         8.136359         4.036716         4.581787
# 4108         4.519018         8.626706         3.253652         4.551400
# 4115         4.725125         8.664279         2.839370         4.178273
# 4136         3.792458         9.119153         2.870142         3.759730
# 4139         3.958901         8.666700         2.812066         4.799163
#
#       ENSG00000001084  ENSG00000001167  ...  ENSG00000285687  ENSG00000285765  \
# ID                                      ...
# 3000         5.434887         6.313419  ...        -3.479269        -3.442632
# 3001         5.556669         6.403626  ...        -2.790381        -2.845587
# 3002         5.340044         6.252896  ...        -3.481981        -3.455701
# 3003         6.446975         6.365839  ...        -3.466844        -2.340830
# 3004         5.111581         6.509765  ...        -3.332901        -3.356088
# ...               ...              ...  ...              ...              ...
# 4102         5.583952         6.584387  ...        -3.048055        -2.786471
# 4108         6.067533         6.208213  ...        -3.110857        -3.133537
# 4115         5.699001         6.455780  ...        -2.977598        -3.008691
# 4136         6.305601         6.054967  ...        -3.264868        -3.273359
# 4139         5.624561         6.235111  ...        -3.236530        -3.262628
#
#       ENSG00000285814  ENSG00000285843  ENSG00000285891  ENSG00000285913  \
# ID
# 3000        -3.478343        -3.364637        -3.487534        -3.487534
# 3001        -2.791950        -2.947585        -2.776044        -2.776044
# 3002        -3.481048        -3.323370        -3.490907        -3.490907
# 3003        -3.464768        -3.303630        -3.477475        -3.477475
# 3004        -3.333370        -3.078897        -3.322814        -3.322814
# ...               ...              ...              ...              ...
# 4102        -3.049144        -2.816837        -3.039936        -3.039936
# 4108        -3.111776        -3.190143        -3.105350        -3.105350
# 4115        -2.978779        -3.080310        -2.969678        -2.969678
# 4136        -3.265123        -3.207870        -3.373228        -3.373228
# 4139        -3.237662        -3.317083        -3.229719        -3.229719
#
#       ENSG00000285937  ENSG00000285946  ENSG00000285950  ENSG00000285975
# ID
# 3000        -3.477212        -3.160921        -3.276003        -3.480959
# 3001        -2.794114        -2.892143        -2.832832        -2.785990
# 3002        -3.479984        -2.779435        -2.944676        -3.483760
# 3003        -3.462194        -3.064134        -3.415254        -3.470379
# 3004        -3.333964        -2.935973        -2.932657        -3.329702
# ...               ...              ...              ...              ...
# 4102        -3.050273        -3.101747        -1.829699        -3.045297
# 4108        -3.113076        -3.159333        -3.128504        -3.108994
# 4115        -2.979836        -2.605039        -3.001129        -2.975235
# 4136        -3.386139        -3.196720        -3.413071        -3.380948
# 4139        -3.238792        -3.284328        -3.080109        -3.234818
#
# [545 rows x 30424 columns]

# %%
factor_ppmi=pd.read_csv(path1/"factor_PPMI_subset_from_PPMI_PDBP_shared_genes_Log2CPM_sex_effect_removed_QuantileNorm_02giu2024.txt",delimiter='\t')
factor_ppmi['ID'] = factor_ppmi['ID'].astype(str)

# %%
combined_ppmi = pd.merge(t_ppmi,factor_ppmi, on='ID')
combined_ppmi
# Out:
#        ID  ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# 0    3000        -0.101375        -2.999518         4.328498         6.049779
# 1    3001        -0.070030        -2.736090         5.246508         6.163900
# 2    3002         1.259571        -1.404902         5.358119         6.074396
# 3    3003        -1.071352        -2.890159         5.247370         6.124415
# 4    3004        -0.499520        -2.414768         5.351478         6.352868
# ..    ...              ...              ...              ...              ...
# 540  4102         0.394976        -3.020122         5.379363         6.271351
# 541  4108        -1.064643        -2.870947         4.891916         6.071242
# 542  4115        -0.626887        -2.947472         5.040913         6.138357
# 543  4136        -1.850876        -2.993623         4.164878         5.503493
# 544  4139        -0.424039        -3.068511         5.312002         6.205509
#
#      ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# 0           4.211890         8.784764         2.173793         4.125101
# 1           4.088958         8.628968         3.412540         4.231814
# 2           4.424164         8.762913         2.727398         4.769609
# 3           4.354913         8.363715         4.113420         4.505387
# 4           4.315031         9.066409         4.021306         4.289712
# ..               ...              ...              ...              ...
# 540         4.256049         8.136359         4.036716         4.581787
# 541         4.519018         8.626706         3.253652         4.551400
# 542         4.725125         8.664279         2.839370         4.178273
# 543         3.792458         9.119153         2.870142         3.759730
# 544         3.958901         8.666700         2.812066         4.799163
#
#      ENSG00000001084  ...  ENSG00000285814  ENSG00000285843  ENSG00000285891  \
# 0           5.434887  ...        -3.478343        -3.364637        -3.487534
# 1           5.556669  ...        -2.791950        -2.947585        -2.776044
# 2           5.340044  ...        -3.481048        -3.323370        -3.490907
# 3           6.446975  ...        -3.464768        -3.303630        -3.477475
# 4           5.111581  ...        -3.333370        -3.078897        -3.322814
# ..               ...  ...              ...              ...              ...
# 540         5.583952  ...        -3.049144        -2.816837        -3.039936
# 541         6.067533  ...        -3.111776        -3.190143        -3.105350
# 542         5.699001  ...        -2.978779        -3.080310        -2.969678
# 543         6.305601  ...        -3.265123        -3.207870        -3.373228
# 544         5.624561  ...        -3.237662        -3.317083        -3.229719
#
#      ENSG00000285913  ENSG00000285937  ENSG00000285946  ENSG00000285950  \
# 0          -3.487534        -3.477212        -3.160921        -3.276003
# 1          -2.776044        -2.794114        -2.892143        -2.832832
# 2          -3.490907        -3.479984        -2.779435        -2.944676
# 3          -3.477475        -3.462194        -3.064134        -3.415254
# 4          -3.322814        -3.333964        -2.935973        -2.932657
# ..               ...              ...              ...              ...
# 540        -3.039936        -3.050273        -3.101747        -1.829699
# 541        -3.105350        -3.113076        -3.159333        -3.128504
# 542        -2.969678        -2.979836        -2.605039        -3.001129
# 543        -3.373228        -3.386139        -3.196720        -3.413071
# 544        -3.229719        -3.238792        -3.284328        -3.080109
#
#      ENSG00000285975  Diagnosis  Sex
# 0          -3.480959        CTR    F
# 1          -2.785990         PD    M
# 2          -3.483760         PD    F
# 3          -3.470379         PD    F
# 4          -3.329702        CTR    M
# ..               ...        ...  ...
# 540        -3.045297         PD    M
# 541        -3.108994         PD    M
# 542        -2.975235         PD    M
# 543        -3.380948         PD    M
# 544        -3.234818        CTR    M
#
# [545 rows x 30427 columns]

# %%
combined_ppmi.to_csv(path1/'ppmi_data.csv', sep='\t')

# %% [markdown]
# # PDBP

# %%
pdbp_ppmi_data=pd.read_csv(path1/"PDBP_subset_from_PPMI_PDBP_shared_genes_Log2CPM_sex_effect_removed_QuantileNorm_02giu2024.txt",delimiter='\t')
t_pdbp = pdbp_ppmi_data.T

# %%
index_pdbp = t_pdbp.reset_index()

# %%
index_pdbp['index']= index_pdbp['index'].str[3:]

# %%
index_pdbp
# Out:
#            index  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# 0     PDLK184WGE        -0.795371        -2.729347         4.132727
# 1     PDXW222GG2         0.029172        -3.487062         5.383310
# 2     PDDY096RP8         0.161952        -2.245680         4.764646
# 3     PDCJ149XWQ        -0.851656        -2.650620         5.398471
# 4     PDYH176ZFA        -0.712838        -2.724630         4.980514
# ...          ...              ...              ...              ...
# 1202  PDZA968YLU        -0.432641        -2.489323         4.779148
# 1203  PDBE349TEN        -0.769956        -2.580791         4.700159
# 1204  PDCJ314NKT        -0.075972        -3.483480         4.797046
# 1205  PDYZ819YLQ        -1.151518        -2.418979         5.472407
# 1206  PDCG654NZL        -0.765584        -2.738868         4.604566
#
#       ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  \
# 0            5.947212         3.915167         9.081336         2.544537
# 1            6.113187         4.208315         8.994625         4.462823
# 2            6.189538         4.310707         8.915631         3.514179
# 3            6.203822         4.209682         8.833031         3.559513
# 4            6.184612         4.256929         8.860026         2.689762
# ...               ...              ...              ...              ...
# 1202         5.963757         4.270477         9.142878         2.490018
# 1203         5.839763         3.898746         9.267990         4.262164
# 1204         6.283134         4.454279         8.577536         3.152542
# 1205         6.263525         4.380882         8.987690         2.924825
# 1206         5.944163         4.198164         9.100145         2.940787
#
#       ENSG00000001036  ENSG00000001084  ...  ENSG00000285687  ENSG00000285765  \
# 0            4.212770         5.115425  ...        -2.784321        -2.838762
# 1            4.380455         5.551275  ...        -3.433885        -3.367082
# 2            4.579706         5.807383  ...        -3.481217        -3.462194
# 3            4.704305         5.508427  ...        -2.240673        -2.789659
# 4            4.447423         5.452709  ...        -2.781719        -2.836982
# ...               ...              ...  ...              ...              ...
# 1202         4.810756         5.216479  ...        -2.589854        -2.695303
# 1203         4.266996         5.253896  ...        -2.670956        -2.754169
# 1204         4.022217         5.745774  ...        -3.419326        -3.350476
# 1205         4.543833         5.547137  ...        -2.521390        -2.639686
# 1206         4.624445         5.570320  ...        -2.792521        -2.845683
#
#       ENSG00000285814  ENSG00000285843  ENSG00000285891  ENSG00000285913  \
# 0           -2.786100        -2.942664        -2.770755        -2.770755
# 1           -3.431357        -3.268287        -3.452658        -3.452658
# 2           -3.480309        -3.362947        -3.490272        -3.490272
# 3           -2.730225        -2.912417        -2.710112        -2.710112
# 4           -2.783305        -2.940982        -2.767595        -2.767595
# ...               ...              ...              ...              ...
# 1202        -2.593489        -2.857318        -2.565912        -2.565912
# 1203        -2.674132        -2.891556        -2.649150        -2.649150
# 1204        -3.416596        -3.247988        -3.442413        -3.442413
# 1205        -2.525174        -2.833294        -2.494825        -2.494825
# 1206        -2.794212        -2.946376        -2.778893        -2.778893
#
#       ENSG00000285937  ENSG00000285946  ENSG00000285950  ENSG00000285975
# 0           -2.788866        -2.887931        -2.825500        -2.781080
# 1           -3.427209        -3.317961        -3.380948        -3.442536
# 2           -3.479424        -3.199985        -3.393907        -3.483213
# 3           -2.733033        -2.850490        -2.775262        -2.722415
# 4           -2.785704        -2.886320        -2.823342        -2.777919
# ...               ...              ...              ...              ...
# 1202        -2.597467        -2.775536        -2.670709        -2.583686
# 1203        -2.678160        -2.821396        -2.735409        -2.664074
# 1204        -3.414100        -3.301836        -3.365560        -3.424378
# 1205        -2.530494        -2.740900        -2.612083        -2.513835
# 1206        -2.796094        -2.892989        -2.832269        -2.788498
#
# [1207 rows x 30425 columns]

# %%
index_pdbp.reset_index(inplace=True)

# %%
index_pdbp.rename(columns={"index":"ID"},inplace=True)

# %%
index_pdbp.set_index('ID', inplace=True)

# %%
index_pdbp
# Out:
#             ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# ID
# PDLK184WGE        -0.795371        -2.729347         4.132727
# PDXW222GG2         0.029172        -3.487062         5.383310
# PDDY096RP8         0.161952        -2.245680         4.764646
# PDCJ149XWQ        -0.851656        -2.650620         5.398471
# PDYH176ZFA        -0.712838        -2.724630         4.980514
# ...                     ...              ...              ...
# PDZA968YLU        -0.432641        -2.489323         4.779148
# PDBE349TEN        -0.769956        -2.580791         4.700159
# PDCJ314NKT        -0.075972        -3.483480         4.797046
# PDYZ819YLQ        -1.151518        -2.418979         5.472407
# PDCG654NZL        -0.765584        -2.738868         4.604566
#
#             ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# ID
# PDLK184WGE         5.947212         3.915167         9.081336
# PDXW222GG2         6.113187         4.208315         8.994625
# PDDY096RP8         6.189538         4.310707         8.915631
# PDCJ149XWQ         6.203822         4.209682         8.833031
# PDYH176ZFA         6.184612         4.256929         8.860026
# ...                     ...              ...              ...
# PDZA968YLU         5.963757         4.270477         9.142878
# PDBE349TEN         5.839763         3.898746         9.267990
# PDCJ314NKT         6.283134         4.454279         8.577536
# PDYZ819YLQ         6.263525         4.380882         8.987690
# PDCG654NZL         5.944163         4.198164         9.100145
#
#             ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ID
# PDLK184WGE         2.544537         4.212770         5.115425
# PDXW222GG2         4.462823         4.380455         5.551275
# PDDY096RP8         3.514179         4.579706         5.807383
# PDCJ149XWQ         3.559513         4.704305         5.508427
# PDYH176ZFA         2.689762         4.447423         5.452709
# ...                     ...              ...              ...
# PDZA968YLU         2.490018         4.810756         5.216479
# PDBE349TEN         4.262164         4.266996         5.253896
# PDCJ314NKT         3.152542         4.022217         5.745774
# PDYZ819YLQ         2.924825         4.543833         5.547137
# PDCG654NZL         2.940787         4.624445         5.570320
#
#             ENSG00000001167  ...  ENSG00000285687  ENSG00000285765  \
# ID                           ...
# PDLK184WGE         6.266301  ...        -2.784321        -2.838762
# PDXW222GG2         5.987634  ...        -3.433885        -3.367082
# PDDY096RP8         6.550710  ...        -3.481217        -3.462194
# PDCJ149XWQ         6.170992  ...        -2.240673        -2.789659
# PDYH176ZFA         6.317944  ...        -2.781719        -2.836982
# ...                     ...  ...              ...              ...
# PDZA968YLU         6.212650  ...        -2.589854        -2.695303
# PDBE349TEN         6.150312  ...        -2.670956        -2.754169
# PDCJ314NKT         6.317370  ...        -3.419326        -3.350476
# PDYZ819YLQ         6.305048  ...        -2.521390        -2.639686
# PDCG654NZL         6.199966  ...        -2.792521        -2.845683
#
#             ENSG00000285814  ENSG00000285843  ENSG00000285891  \
# ID
# PDLK184WGE        -2.786100        -2.942664        -2.770755
# PDXW222GG2        -3.431357        -3.268287        -3.452658
# PDDY096RP8        -3.480309        -3.362947        -3.490272
# PDCJ149XWQ        -2.730225        -2.912417        -2.710112
# PDYH176ZFA        -2.783305        -2.940982        -2.767595
# ...                     ...              ...              ...
# PDZA968YLU        -2.593489        -2.857318        -2.565912
# PDBE349TEN        -2.674132        -2.891556        -2.649150
# PDCJ314NKT        -3.416596        -3.247988        -3.442413
# PDYZ819YLQ        -2.525174        -2.833294        -2.494825
# PDCG654NZL        -2.794212        -2.946376        -2.778893
#
#             ENSG00000285913  ENSG00000285937  ENSG00000285946  \
# ID
# PDLK184WGE        -2.770755        -2.788866        -2.887931
# PDXW222GG2        -3.452658        -3.427209        -3.317961
# PDDY096RP8        -3.490272        -3.479424        -3.199985
# PDCJ149XWQ        -2.710112        -2.733033        -2.850490
# PDYH176ZFA        -2.767595        -2.785704        -2.886320
# ...                     ...              ...              ...
# PDZA968YLU        -2.565912        -2.597467        -2.775536
# PDBE349TEN        -2.649150        -2.678160        -2.821396
# PDCJ314NKT        -3.442413        -3.414100        -3.301836
# PDYZ819YLQ        -2.494825        -2.530494        -2.740900
# PDCG654NZL        -2.778893        -2.796094        -2.892989
#
#             ENSG00000285950  ENSG00000285975
# ID
# PDLK184WGE        -2.825500        -2.781080
# PDXW222GG2        -3.380948        -3.442536
# PDDY096RP8        -3.393907        -3.483213
# PDCJ149XWQ        -2.775262        -2.722415
# PDYH176ZFA        -2.823342        -2.777919
# ...                     ...              ...
# PDZA968YLU        -2.670709        -2.583686
# PDBE349TEN        -2.735409        -2.664074
# PDCJ314NKT        -3.365560        -3.424378
# PDYZ819YLQ        -2.612083        -2.513835
# PDCG654NZL        -2.832269        -2.788498
#
# [1207 rows x 30424 columns]

# %%
factor_pdbp=pd.read_csv(path1/"factor_PDBP_subset_from_PPMI_PDBP_shared_genes_Log2CPM_sex_effect_removed_QuantileNorm_02giu2024.txt",delimiter='\t')
factor_pdbp
# Out:
#                  ID Diagnosis Sex
# 0     PD_PDLK184WGE        PD   M
# 1     PD_PDXW222GG2        PD   F
# 2     PD_PDDY096RP8       CTR   F
# 3     PD_PDCJ149XWQ        PD   M
# 4     PD_PDYH176ZFA       CTR   M
# ...             ...       ...  ..
# 1202  PD_PDZA968YLU        PD   M
# 1203  PD_PDBE349TEN       CTR   M
# 1204  PD_PDCJ314NKT       CTR   F
# 1205  PD_PDYZ819YLQ        PD   M
# 1206  PD_PDCG654NZL        PD   M
#
# [1207 rows x 3 columns]

# %%
factor_pdbp['ID'] = factor_pdbp['ID'].str[3:]
factor_pdbp
# Out:
#               ID Diagnosis Sex
# 0     PDLK184WGE        PD   M
# 1     PDXW222GG2        PD   F
# 2     PDDY096RP8       CTR   F
# 3     PDCJ149XWQ        PD   M
# 4     PDYH176ZFA       CTR   M
# ...          ...       ...  ..
# 1202  PDZA968YLU        PD   M
# 1203  PDBE349TEN       CTR   M
# 1204  PDCJ314NKT       CTR   F
# 1205  PDYZ819YLQ        PD   M
# 1206  PDCG654NZL        PD   M
#
# [1207 rows x 3 columns]

# %%
combined_pdbp = pd.merge(index_pdbp, factor_pdbp, on="ID")

# %%
combined_pdbp.to_csv(path1/"pdbp_data.csv",sep='\t')

# %%
current_date = datetime.now().date()
print("Last update :", current_date)
# Out:
# Last update : 2024-07-25
